# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("../data/ASI_and_af.csv", sep=",", index_col=0)

# %%
df
# Out:
#     id subscale                                               item  \
# 0    1        B  No matter how accomplished he is, a man is not...
# 1    2        H  Many women are actually seeking special favors...
# 2    3        B  In a disaster, women ought not necessarily to ...
# 3    4        H  Most women interpret innocent remarks or acts ...
# 4    5        H                     Women are too easily offended.
# 5    6        B  People are often truly happy in life without b...
# 6    7        H  Feminists are not seeking for women to have mo...
# 7    8        B  Many women have a quality of purity that few m...
# 8    9        B    Women should be cherished and protected by men.
# 9   10        H  Most women fail to appreciate fully all that m...
# 10  11        H  Women seek to gain power by getting control ov...
# 11  12        B    Every man ought to have a woman whom he adores.
# 12  13        B                    Men are complete without women.
# ...

# %%
df = df.drop("item", axis=1)
df = df.rename({"alternate form":"item"}, axis=1)

# %%
df
# Out:
#     id subscale                                               item  reversed
# 0    1        B  A man's sense of true fulfillment is deeply ro...     False
# 1    2        H  Some women, while advocating for 'equality,' m...     False
# 2    3        B  In times of crisis, women's survival ought not...      True
# 3    4        H  Many women tend to perceive harmless comments ...     False
# 4    5        H  Women have a tendency to be too quick to take ...     False
# 5    6        B  Happiness and fulfillment can be achieved with...      True
# 6    7        H  Feminists are not aiming for women to dominate...      True
# 7    8        B  Many women possess a degree of moral integrity...     False
# 8    9        B  Men should provide a safe and nurturing enviro...     False
# 9   10        H  Most women do not fully recognize or value eve...     False
# 10  11        H  Women often attempt to exert influence over me...     False
# ...

# %%
df.to_csv("../data/ASI_af.csv", sep=",")
