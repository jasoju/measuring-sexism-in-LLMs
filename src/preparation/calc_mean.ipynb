# %%
import pandas as pd

# %%
df= pd.read_json(f"../../results/MFQ/rel_eval_changed_eos.json")

# %%
df
# Out:
#                                     0                      1   \
# model_name      Llama-3.1-70B-Instruct  Llama-3.1-8B-Instruct
# fraction_match                0.655172               0.633333
#
#                                    2                       3   \
# model_name      Llama-3.1-Centaur-70B  Llama-3.3-70B-Instruct
# fraction_match               0.866667                0.933333
#
#                                       4                     5   \
# model_name      Mistral-7B-Instruct-v0.3  Qwen2.5-14B-Instruct
# fraction_match                  0.833333              0.766667
#
#                                   6                    7   \
# model_name      Qwen2.5-32B-Instruct  Qwen2.5-7B-Instruct
# fraction_match              0.866667             0.766667
#
#                                     8               9              10  \
# model_name      Qwen3-4B-Instruct-2507  gemma-3-12b-it  gemma-3-1b-it
# fraction_match                0.833333        0.766667       0.533333
#
# ...

# %%
print(df.loc["fraction_match"].mean())
print(df.loc["fraction_match"].std())
# Out:
# 0.7760389036307694
# 0.11186969823615583
