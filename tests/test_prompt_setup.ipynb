# %% [markdown]
# # !!! MOVE TO SRC

# %%
from utils.prompt_setup import create_df

# %%
df = create_df("chatbot_arena_conv", "ASI")

df
# Out:
#       item_id subscale                                               item  \
# 0           1        B  No matter how accomplished he is, a man is not...
# 1           1        B  No matter how accomplished he is, a man is not...
# 2           1        B  No matter how accomplished he is, a man is not...
# 3           1        B  No matter how accomplished he is, a man is not...
# 4           1        B  No matter how accomplished he is, a man is not...
# ...       ...      ...                                                ...
# 6595       22        B  Women, as compared to men, tend to have a more...
# 6596       22        B  Women, as compared to men, tend to have a more...
# 6597       22        B  Women, as compared to men, tend to have a more...
# 6598       22        B  Women, as compared to men, tend to have a more...
# 6599       22        B  Women, as compared to men, tend to have a more...
#
#       reversed                       question_id                    model  \
# ...

# %%
df.loc[0, :]["prompt"]
# Out:
# [{'content': 'How can I determine how many people an aircraft carrier would need to operate?',
#   'role': 'user'},
#  {'content': 'The number of people required to operate an aircraft carrier depends on several factors, including the size of the ship, the type of aircraft it operates, and the mission it is tasked with.\n\nOn average, an aircraft carrier typically has a crew of around 3,000 to 4,000 personnel, including sailors, pilots, and support staff. However, the exact number of personnel required can vary widely depending on the specific ship and its mission.\n\nIn addition to the crew, an aircraft carrier may also have a number of military personnel on board, including Marines and airmen, who are responsible for operating the aircraft and providing support during missions.\n\nOverall, the exact number of personnel required to operate an aircraft carrier is determined by a variety of factors, and can vary widely depending on the specific ship and its mission.',
# ...
